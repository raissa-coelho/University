# %%
x = 40270304
y = 14819435

pc = (100*y)/x
print(pc)
# Out:
# 36.799908438734406

# %%
x = 548177182
y = 157214149

pc = (100*y)/x
print(pc)
# Out:
# 28.67944054628673

# %%
import numpy as np
import matplotlib.pyplot as plt

#EXPERIMENTO 1
plt.title("Instruções - GCC_4", fontsize = '15')
plt.ylabel("Misses", fontsize = '15')
plt.xlabel("Tipo de Mapeamento", fontsize = '15')
plt.grid()
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.plot(['Direto', 'Associativo\n2way', 'Associativo\n4way', 'Totalmente\nAssociativo'],[23336997, 22955098, 22536579, 22554865],color = 'red', linestyle = 'dashed', marker = 'o')

# %%
plt.title("Dados - GCC_4", fontsize = '15')
plt.ylabel("Misses", fontsize = '15')
plt.xlabel("Tipo de Mapeamento", fontsize = '15')
plt.grid()
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.plot(['Direto', 'Associativo\n2way', 'Associativo\n4way', 'Totalmente\nAssociativo'], [2936655,  2580940, 2506708, 2469340 ], color = 'blue', linestyle = 'dashed', marker = 'o')

# %%
plt.title("Instruções - GO_1", fontsize = '15')
plt.ylabel("Misses", fontsize = '15')
plt.xlabel("Tipo de Mapeamento", fontsize = '15')
plt.grid()
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.plot(['Direto', 'Associativo\n2way', 'Associativo\n4way', 'Totalmente\nAssociativo'], [357785524,355885284,356712392,360636191], color = 'red', linestyle = 'dashed', marker = 'o')

# %%
plt.title("Dados - GO_1", fontsize = '15')
plt.ylabel("Misses", fontsize = '15')
plt.xlabel("Tipo de Mapeamento",  fontsize = '15')
plt.grid()
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.plot(['Direto', 'Associativo\n2way', 'Associativo\n4way', 'Totalmente\nAssociativo'], [42172325,37853704,36322153,35520130], color = 'blue', linestyle = 'dashed', marker = 'o')

# %%
TaxaI = [0.5795, 0.5710, 0.5596, 0.5611]
TaxaD = [0.1967, 0.1731, 0.1679, 0.1656]
X = ['Direto', 'Associativo\n2way', 'Associativo\n4way', 'Totalmente\nAssociativo']

axiX = np.arange(len(X))

plt.bar(axiX - 0.2, TaxaI, 0.4, label = 'Instruções')
plt.bar(axiX + 0.2 , TaxaD, 0.4, label = 'Dados' )

plt.xticks(axiX, X)
plt.ylabel("Miss Rate", fontsize = '15')
plt.xlabel("Tipo de Mapeamento", fontsize = '15')
plt.title("GCC_4", fontsize = '15')
plt.legend()
plt.show()

# %%
TaxaI = [0.6527, 0.6492, 0.6507, 0.6579]
TaxaD = [0.2682, 0.2408, 0.2310, 0.2259]
X = ['Direto', 'Associativo\n2way', 'Associativo\n4way', 'Totalmente\nAssociativo']

axiX = np.arange(len(X))

plt.bar(axiX - 0.2, TaxaI, 0.4, label = 'Instruções')
plt.bar(axiX + 0.2 , TaxaD, 0.4, label = 'Dados' )

plt.xticks(axiX, X)
plt.ylabel("Miss Rate", fontsize = '15')
plt.xlabel("Tipo de Mapeamento", fontsize = '15')
plt.title("GO_1", fontsize = '15')
plt.legend()
plt.show()

# %%
x = ['Outras Intsruções', 'Instruções L/S']
dd = 40270304 - 14819435
y = [dd,14819435]

def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.1f}%\n({:d})".format(pct, absolute)

plt.title("GCC_4", fontsize = '15')
plt.pie(y, labels = x, autopct= lambda pct: func(pct, y))
plt.show()

# %%
x = ['Outras Instruções', 'Instruções L/S executadas']
dd2 = 548177182 - 157214149
y = [dd2 , 157214149]

def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.1f}%\n({:d})".format(pct, absolute)

plt.title("GO_1", fontsize = '15')
plt.pie(y, labels = x, autopct= lambda pct: func(pct, y))
plt.show()

# %%
#EXPERIMENTO 2

plt.tight_layout(h_pad=2)

plt.subplot(211)
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.title("Instruções - GCC_4", fontsize = '15')
plt.ylabel("Misses", fontsize = '15')
plt.plot(['LRU','FIFO','RANDOM'],[10125497,10510258,10497412],color = 'red', linestyle = 'dashed', marker = 'o')

plt.subplot(212)
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.ylabel("Replacement", fontsize = '15')
plt.xlabel("Política de Substituição", fontsize = '15')
plt.plot(['LRU','FIFO','RANDOM'],[10125369,10510130,10497284],color = 'red', linestyle = 'dashed', marker = 'o')

# %%
plt.tight_layout(h_pad=2)

plt.subplot(211)
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.title("Dados - GCC_4", fontsize = '15')
plt.ylabel("Misses", fontsize = '15')
plt.plot(['LRU','FIFO','RANDOM'],[1181576,1353425,1352846],color = 'blue', linestyle = 'dashed', marker = 'o')

plt.subplot(212)
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.ylabel("Replacement", fontsize = '15')
plt.xlabel("Política de Substituição", fontsize = '15')
plt.plot(['LRU','FIFO','RANDOM'],[1181448,1353297,1352718],color = 'blue', linestyle = 'dashed', marker = 'o')

# %%
plt.tight_layout(h_pad=2)

plt.subplot(211)
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.title("Instruções - GO_1", fontsize = '15')
plt.ylabel("Misses", fontsize = '15')
plt.plot(['LRU','FIFO','RANDOM'],[158772892,159819864,161248157],color = 'red', linestyle = 'dashed', marker = 'o')

plt.subplot(212)
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.ylabel("Replacement", fontsize = '15')
plt.xlabel("Política de Substituição", fontsize = '15')
plt.plot(['LRU','FIFO','RANDOM'],[158772764,159819736,161248029],color = 'red', linestyle = 'dashed', marker = 'o')

# %%
plt.tight_layout(h_pad=2)

plt.subplot(211)
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.title("Dados - GO_1", fontsize = '15')
plt.ylabel("Misses", fontsize = '15')
plt.plot(['LRU','FIFO','RANDOM'],[19886098,23208029,25173670 ],color = 'blue', linestyle = 'dashed', marker = 'o')

plt.subplot(212)
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.ylabel("Replacement", fontsize = '15')
plt.xlabel("Política de Substituição", fontsize = '15')
plt.plot(['LRU','FIFO','RANDOM'],[19885970,23207901,25173542],color = 'blue', linestyle = 'dashed', marker = 'o')

# %%
#EXPERIMENTO 3
plt.tight_layout(h_pad=4)

plt.subplot(211)
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.title("Instruções - GCC_4", fontsize = '15')
plt.ylabel("Misses", fontsize = '15')
plt.plot(['16','32','64','128'],[10850680,6630992,4300101,2975003],color = 'red', linestyle = 'dashed', marker = 'o')

plt.subplot(212)
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.title("Dados", fontsize = '15')
plt.ylabel("Misses", fontsize = '15')
plt.xlabel("Tamanho do bloco(em bytes)", fontsize = '15')
plt.plot(['16','32','64','128'],[1469843,1441282,1519990,1855458],color = 'red', linestyle = 'dashed', marker = 'o')

# %%
plt.tight_layout(h_pad=4)

plt.subplot(211)
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.title("Instruções - GO_1", fontsize = '15')
plt.ylabel("Misses", fontsize = '15')
plt.plot(['16','32','64','128'],[158269086 ,88084643,51700025,31940622],color = 'blue', linestyle = 'dashed', marker = 'o')

plt.subplot(212)
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.title("Dados", fontsize = '15')
plt.ylabel("Misses", fontsize = '15')
plt.xlabel("Tamanho do bloco(em bytes)", fontsize = '15')
plt.plot(['16','32','64','128'],[27551407,36027244,45118515,54209465],color = 'blue', linestyle = 'dashed', marker = 'o')

# %%
#EXPERIMENTO 4

x = np.array(['Caches Separadas', 'Cache Unificada'])
y = np.array([65.24,39.59])

plt.ylabel("Misses(em %)", fontsize = '15')
plt.xlabel("Caches", fontsize = '15')
plt.bar(x,y, width=0.5, color = 'black')
plt.show()
