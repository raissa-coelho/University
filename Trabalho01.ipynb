# %%
x = 40270304
y = 15946706

pc = (100*y)/x
print(pc)
# Out:
# 39.59916965116528

# %%
x = 40270304
y = 26273652

pc = (100*y)/x
print(pc)
# Out:
# 65.24324226606285

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.title("Instruções - GCC_4")
plt.ylabel("Misses")
plt.xlabel("Tipo de Mapeamento")
plt.grid()
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.plot(['Direto', 'Associativo 2way', 'Associativo 4way', 'Totalmente Associativo'],[23336997, 22955098, 22536579, 22554865],color = 'red', linestyle = 'dashed', marker = 'o')

# %%
plt.title("Dados - GCC_4")
plt.ylabel("Misses")
plt.xlabel("Tipo de Mapeamento")
plt.grid()
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.plot(['Direto', 'Associativo 2way', 'Associativo 4way', 'Totalmente Associativo'], [2936655,  2580940, 2506708, 2469340 ], color = 'blue', linestyle = 'dashed', marker = 'o')

# %%
plt.title("Instruções - GO_1")
plt.ylabel("Misses")
plt.xlabel("Tipo de Mapeamento")
plt.grid()
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.plot(['Direto', 'Associativo 2way', 'Associativo 4way', 'Totalmente Associativo'], [357785524,355885284,356712392,360636191], color = 'red', linestyle = 'dashed', marker = 'o')

# %%
plt.title("Dados - GO_1")
plt.ylabel("Misses")
plt.xlabel("Tipo de Mapeamento")
plt.grid()
plt.ticklabel_format( style = 'plain', axis = 'y')
plt.plot(['Direto', 'Associativo 2way', 'Associativo 4way', 'Totalmente Associativo'], [42172325,37853704,36322153,35520130], color = 'blue', linestyle = 'dashed', marker = 'o')

# %%
TaxaI = [0.5795, 0.5710, 0.5596, 0.5611]
TaxaD = [0.1967, 0.1731, 0.1679, 0.1656]
X = ['Direto', 'Associativo 2way', 'Associativo 4way', 'Totalmente Associativo']

axiX = np.arange(len(X))

plt.bar(axiX - 0.2, TaxaI, 0.4, label = 'Instruções')
plt.bar(axiX + 0.2 , TaxaD, 0.4, label = 'Dados' )

plt.xticks(axiX, X)
plt.ylabel("Miss Rate")
plt.xlabel("Tipo de Mapeamento")
plt.title("GCC_4")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
